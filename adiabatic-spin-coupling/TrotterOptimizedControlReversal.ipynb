# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.circuit import Parameter, Gate
from qiskit_aer.primitives import Sampler

def XX_interaction(N, M, beta, cxx, qc):
    # Horizontal interactions
    for row in range(N):
        for col in range(M - 1):
            i = row * M + col
            qc.h(i)
            qc.h(i + 1)
            qc.cx(i, i + 1)
            qc.rz(cxx * beta, i + 1)
            qc.cx(i, i + 1)

    # Vertical interactions
    for row in range(N - 1):
        for col in range(M):
            i = row * M + col
            qc.cx(i, i + M)
            qc.rz(cxx * beta, i + M)
            qc.cx(i, i + M)
            qc.h(i)
            qc.h(i + M)

def YY_interaction(N, M, beta, cyy, qc):
    # Horizontal interactions
    for row in range(N):
        for col in range(M - 1):
            i = row * M + col
            qc.rx(-np.pi/2, i)
            qc.rx(-np.pi/2, i + 1)
            qc.cx(i, i + 1)
            qc.rz(cyy * beta, i + 1)
            qc.cx(i, i + 1)

    # Vertical interactions
    for row in range(N - 1):
        for col in range(M):
            i = row * M + col
            qc.cx(i, i + M)
            qc.rz(cyy * beta, i + M)
            qc.cx(i, i + M)
            qc.rx(np.pi/2, i)
            qc.rx(np.pi/2, i + M)

# Transverse magnetic field
def magn_interaction(N, M, beta, hz, qc):
    for i in range(N * M):
        qc.rz(2 * hz * beta, i) # Factor of 2 since that is how we defined the Second-Order Trotterization

def rodeo_cycle(N, M, t: Parameter, r, cxx, cyy, hz, targ: Parameter):
    beta = t / r # Parameter for rotation gates
    sys = QuantumRegister(N * M, 's')
    aux = QuantumRegister(1, 'a')
    qc = QuantumCircuit(sys, aux)

    # Initialize ancilla qubit to be in superposition
    qc.h(aux[0])

    # Add Y reversal gates to odd, X reversal gates to even qubits
    for row in range(N):
        for col in range(M):
            idx = row * M + col
            if (row + col) % 2 == 0:
                qc.cx(aux[0], sys[idx])
            else:
                qc.cy(aux[0], sys[idx])

    # Trotter time evolution
    for _ in range(r):
        XX_interaction(N, M, beta, cxx, qc)
        YY_interaction(N, M, beta, cyy, qc)
        magn_interaction(N, M, beta, hz, qc)
        YY_interaction(N, M, beta, cyy, qc)
        XX_interaction(N, M, beta, cxx, qc)

    # Add reversal gates at end
    for row in range(N):
        for col in range(M):
            idx = row * M + col
            if (row + col) % 2 == 0:
                qc.cx(aux[0], sys[idx])
            else:
                qc.cy(aux[0], sys[idx])
                
    # Add phase gate to ancilla
    qc.p(2*targ * t, aux[0])

    # Revert superposition
    qc.h(aux[0])

    return qc.to_gate(label=f"Rodeo_Cycle_{r}_Trotter_Steps")

# Parameters
N = 2
M = 2
cxx = 0.5 * 0.2 * np.pi
cyy = 0.5 * 0.2 * np.pi
hz = 0.5 * 2 * np.pi
numqubits = N * M
cycles = 3

# Initialize system parameters
sysqubits = 1
timeresamples = 10

# Create Target and t parameters
targ = Parameter(r'$E_\odot$')
t = [Parameter(fr'$t_{i}$') for i in range(cycles)]
r = 5

# Create a list of target energies at the same length of the cycle
targ_list = [targ] * cycles

# Create registers and circuit
classical = ClassicalRegister(cycles, 'c')
aux = QuantumRegister(1, 'a')
sys = QuantumRegister(numqubits, 's')
circuit = QuantumCircuit(classical, sys, aux)

# circuit.x(0)

# Create circuit
for j in range(cycles):
    circuit.append(rodeo_cycle(N, M, t[j], r, cxx, cyy, hz, targ_list[j]), range(1 + numqubits))
    circuit.measure(aux, classical[j])

circuit.draw(output='mpl')

# %%
import numpy as np
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.circuit import Parameter, Gate
from qiskit_aer.primitives import Sampler

def XX_interaction(N, M, beta, cxx, qc):
    # Horizontal interactions
    for row in range(N):
        for col in range(M - 1):
            i = row * M + col
            qc.h(i)
            qc.h(i + 1)
            qc.cx(i, i + 1)
            qc.rz(cxx * beta, i + 1)
            qc.cx(i, i + 1)

    # Vertical interactions
    for row in range(N - 1):
        for col in range(M):
            i = row * M + col
            qc.cx(i, i + M)
            qc.rz(cxx * beta, i + M)
            qc.cx(i, i + M)
            qc.h(i)
            qc.h(i + M)

def YY_interaction(N, M, beta, cyy, qc):
    # Horizontal interactions
    for row in range(N):
        for col in range(M - 1):
            i = row * M + col
            qc.rx(-np.pi/2, i)
            qc.rx(-np.pi/2, i + 1)
            qc.cx(i, i + 1)
            qc.rz(cyy * beta, i + 1)
            qc.cx(i, i + 1)

    # Vertical interactions
    for row in range(N - 1):
        for col in range(M):
            i = row * M + col
            qc.cx(i, i + M)
            qc.rz(cyy * beta, i + M)
            qc.cx(i, i + M)
            qc.rx(np.pi/2, i)
            qc.rx(np.pi/2, i + M)

# Transverse magnetic field
def magn_interaction(N, M, beta, hz, qc):
    for i in range(N * M):
        qc.rz(2 * hz * beta, i) # Factor of 2 since that is how we defined the Second-Order Trotterization

def rodeo_cycle(N, M, t: Parameter, r, cxx, cyy, hz, targ: Parameter):
    beta = t / r # Parameter for rotation gates
    sys = QuantumRegister(N * M, 's')
    aux = QuantumRegister(1, 'a')
    qc = QuantumCircuit(sys, aux)

    # Initialize ancilla qubit to be in superposition
    qc.h(aux[0])

    # Add Y reversal gates to odd, X reversal gates to even qubits
    for row in range(N):
        for col in range(M):
            idx = row * M + col
            if (row + col) % 2 == 0:
                qc.cx(aux[0], sys[idx])
            else:
                qc.cy(aux[0], sys[idx])

    # Trotter time evolution
    for _ in range(r):
        XX_interaction(N, M, beta, cxx, qc)
        YY_interaction(N, M, beta, cyy, qc)
        magn_interaction(N, M, beta, hz, qc)
        YY_interaction(N, M, beta, cyy, qc)
        XX_interaction(N, M, beta, cxx, qc)

    # Add reversal gates at end
    for row in range(N):
        for col in range(M):
            idx = row * M + col
            if (row + col) % 2 == 0:
                qc.cx(aux[0], sys[idx])
            else:
                qc.cy(aux[0], sys[idx])
                
    # Add phase gate to ancilla
    qc.p(2*targ * t, aux[0])

    # Revert superposition
    qc.h(aux[0])

    return qc.to_gate(label=f"Rodeo_Cycle_{r}_Trotter_Steps")

# Parameters
N = 2
M = 2
cxx = 0.5 * 0.2 * np.pi
cyy = 0.5 * 0.2 * np.pi
hz = 0.5 * 2 * np.pi
numqubits = N * M
cycles = 3

# Initialize system parameters
sysqubits = 1
timeresamples = 10

# Create Target and t parameters
targ = Parameter(r'$E_\odot$')
t = [Parameter(fr'$t_{i}$') for i in range(cycles)]
r = 5

# Create a list of target energies at the same length of the cycle
targ_list = [targ] * cycles

# Create registers and circuit
classical = ClassicalRegister(cycles, 'c')
aux = QuantumRegister(1, 'a')
sys = QuantumRegister(numqubits, 's')
circuit = QuantumCircuit(classical, sys, aux)

# circuit.x(0)

# Create circuit
for j in range(cycles):
    circuit.append(rodeo_cycle(N, M, t[j], r, cxx, cyy, hz, targ_list[j]), range(1 + numqubits))
    circuit.measure(aux, classical[j])

circuit.draw(output='mpl')

# %%
gamma = 2
for _ in range(timeresamples):
    tsamples = ((1 / gamma) * np.abs(np.random.randn(cycles))).tolist()
    #parameter_binds.append({t[i]: tsamples[i] for i in range(cycles)})
    
parameter_binds = zip(t, tsamples)
parameters = dict(parameter_binds)

target = {targ : -12.5}
    
circuit1 = circuit.assign_parameters(parameters, inplace =False)
circuit2 = circuit1.assign_parameters(target, inplace = False)
circuit2.draw(output= 'mpl')

# %%
sampler = Sampler()

job = sampler.run(circuit2)

job.result()

quasi_dists = job.result().quasi_dists

print(quasi_dists)
# Out:
# [{0: 0.998046875, 7: 0.001953125}]

# %%
# Enumerate scan energies
energymin = -15
energymax = 15
stepsize = 0.1

targetenergies = np.linspace(energymin, energymax, int((energymax-energymin)/stepsize))
targetenergynum = len(targetenergies)
print("Number of target energies:", targetenergynum)

#Energy window, which should to be slightly larger than stepsize in scan
# Is inverse of sigma parameter
gamma = 1

# Amount of "scrambling" of t per target energy. The more random the t the better. 
timeresamples = 10 # Resampling of times for given target energy
shots_per_same_time = 1024

# Create empty list for data
data = []

# Loop through energy list
for i in range(len(targetenergies)):
    
    # Creates dictionary for target energy parameter
    targ_energy = {targ : targetenergies[i]}

    # Below is a troubleshooting line you can use to see if the code is scanning through energies properly
    print("Executing for Target Energy:", targ_energy)
    
    # Initialize a list that will contain the results of all 10 resamples for 1 target energy
    targetenergyrun = []
    for _ in range(timeresamples):
        # Creates random time samples for 1 run
        tsamples = ((1 / gamma) * np.random.randn(cycles)).tolist()
        
        # Creates a dictionary to be able to bind time samples to time parameters
        time_parameter_binds = zip(t, tsamples)
        time_parameters = dict(time_parameter_binds)
        
        # Assigns target energy and time values to parameters
        circuit1 = circuit.assign_parameters(time_parameters, inplace =False)
        circuit2 = circuit1.assign_parameters(targ_energy, inplace = False)
        
        # Runs simulation of circuit with values
        sampler = Sampler()
        job = sampler.run(circuit2)
        job.result()
        quasi_dists = job.result().quasi_dists
        
        # Appends the results to list for this target energy
        targetenergyrun.append(quasi_dists)
    
    # The output from above needs to be post-processed as shown below to gain meaning from it:

    # Flattens list of list of dictionaries into just a list of dictionaries
    flattened_list = []
    for sublist in targetenergyrun:
        flattened_list.extend(sublist)

    # Sums and average dictionaries from multiple timeresamples
    combined_dict = {} 
    for dictionary in flattened_list:
        for key, value in dictionary.items():
            combined_dict[key] = combined_dict.get(key, 0) + value

    average_dict = {}
    for key in combined_dict:
        average_dict[key] = combined_dict[key] / timeresamples

    data.append(average_dict)
# Out:
# Number of target energies: 300
# Executing for Target Energy: {Parameter($E_\odot$): -15.0}
# Executing for Target Energy: {Parameter($E_\odot$): -14.899665551839465}
# Executing for Target Energy: {Parameter($E_\odot$): -14.799331103678929}
# Executing for Target Energy: {Parameter($E_\odot$): -14.698996655518394}
# Executing for Target Energy: {Parameter($E_\odot$): -14.59866220735786}
# Executing for Target Energy: {Parameter($E_\odot$): -14.498327759197325}
# Executing for Target Energy: {Parameter($E_\odot$): -14.397993311036789}
# Executing for Target Energy: {Parameter($E_\odot$): -14.297658862876254}
# Executing for Target Energy: {Parameter($E_\odot$): -14.19732441471572}
# Executing for Target Energy: {Parameter($E_\odot$): -14.096989966555183}
# Executing for Target Energy: {Parameter($E_\odot$): -13.996655518394649}
# Executing for Target Energy: {Parameter($E_\odot$): -13.896321070234114}
# Executing for Target Energy: {Parameter($E_\odot$): -13.795986622073578}
# Executing for Target Energy: {Parameter($E_\odot$): -13.695652173913043}
# Executing for Target Energy: {Parameter($E_\odot$): -13.595317725752508}
# Executing for Target Energy: {Parameter($E_\odot$): -13.494983277591974}
# Executing for Target Energy: {Parameter($E_\odot$): -13.394648829431437}
# Executing for Target Energy: {Parameter($E_\odot$): -13.294314381270903}
# Executing for Target Energy: {Parameter($E_\odot$): -13.193979933110368}
# Executing for Target Energy: {Parameter($E_\odot$): -13.093645484949832}
# Executing for Target Energy: {Parameter($E_\odot$): -12.993311036789297}
# Executing for Target Energy: {Parameter($E_\odot$): -12.892976588628763}
# Executing for Target Energy: {Parameter($E_\odot$): -12.792642140468228}
# Executing for Target Energy: {Parameter($E_\odot$): -12.692307692307692}
# Executing for Target Energy: {Parameter($E_\odot$): -12.591973244147157}
# Executing for Target Energy: {Parameter($E_\odot$): -12.491638795986622}
# Executing for Target Energy: {Parameter($E_\odot$): -12.391304347826086}
# Executing for Target Energy: {Parameter($E_\odot$): -12.290969899665551}
# Executing for Target Energy: {Parameter($E_\odot$): -12.190635451505017}
# Executing for Target Energy: {Parameter($E_\odot$): -12.090301003344482}
# Executing for Target Energy: {Parameter($E_\odot$): -11.989966555183946}
# Executing for Target Energy: {Parameter($E_\odot$): -11.889632107023411}
# Executing for Target Energy: {Parameter($E_\odot$): -11.789297658862877}
# Executing for Target Energy: {Parameter($E_\odot$): -11.68896321070234}
# Executing for Target Energy: {Parameter($E_\odot$): -11.588628762541806}
# Executing for Target Energy: {Parameter($E_\odot$): -11.488294314381271}
# Executing for Target Energy: {Parameter($E_\odot$): -11.387959866220736}
# Executing for Target Energy: {Parameter($E_\odot$): -11.2876254180602}
# Executing for Target Energy: {Parameter($E_\odot$): -11.187290969899665}
# Executing for Target Energy: {Parameter($E_\odot$): -11.08695652173913}
# Executing for Target Energy: {Parameter($E_\odot$): -10.986622073578594}
# Executing for Target Energy: {Parameter($E_\odot$): -10.88628762541806}
# Executing for Target Energy: {Parameter($E_\odot$): -10.785953177257525}
# Executing for Target Energy: {Parameter($E_\odot$): -10.68561872909699}
# Executing for Target Energy: {Parameter($E_\odot$): -10.585284280936456}
# Executing for Target Energy: {Parameter($E_\odot$): -10.48494983277592}
# Executing for Target Energy: {Parameter($E_\odot$): -10.384615384615383}
# Executing for Target Energy: {Parameter($E_\odot$): -10.284280936454849}
# Executing for Target Energy: {Parameter($E_\odot$): -10.183946488294314}
# Executing for Target Energy: {Parameter($E_\odot$): -10.08361204013378}
# Executing for Target Energy: {Parameter($E_\odot$): -9.983277591973245}
# Executing for Target Energy: {Parameter($E_\odot$): -9.88294314381271}
# Executing for Target Energy: {Parameter($E_\odot$): -9.782608695652174}
# Executing for Target Energy: {Parameter($E_\odot$): -9.682274247491637}
# Executing for Target Energy: {Parameter($E_\odot$): -9.581939799331103}
# Executing for Target Energy: {Parameter($E_\odot$): -9.481605351170568}
# Executing for Target Energy: {Parameter($E_\odot$): -9.381270903010034}
# Executing for Target Energy: {Parameter($E_\odot$): -9.280936454849499}
# Executing for Target Energy: {Parameter($E_\odot$): -9.180602006688963}
# Executing for Target Energy: {Parameter($E_\odot$): -9.080267558528428}
# Executing for Target Energy: {Parameter($E_\odot$): -8.979933110367892}
# Executing for Target Energy: {Parameter($E_\odot$): -8.879598662207357}
# Executing for Target Energy: {Parameter($E_\odot$): -8.779264214046822}
# Executing for Target Energy: {Parameter($E_\odot$): -8.678929765886288}
# Executing for Target Energy: {Parameter($E_\odot$): -8.578595317725753}
# Executing for Target Energy: {Parameter($E_\odot$): -8.478260869565217}
# Executing for Target Energy: {Parameter($E_\odot$): -8.377926421404682}
# Executing for Target Energy: {Parameter($E_\odot$): -8.277591973244146}
# Executing for Target Energy: {Parameter($E_\odot$): -8.177257525083611}
# Executing for Target Energy: {Parameter($E_\odot$): -8.076923076923077}
# Executing for Target Energy: {Parameter($E_\odot$): -7.976588628762542}
# Executing for Target Energy: {Parameter($E_\odot$): -7.8762541806020065}
# Executing for Target Energy: {Parameter($E_\odot$): -7.775919732441471}
# Executing for Target Energy: {Parameter($E_\odot$): -7.6755852842809364}
# Executing for Target Energy: {Parameter($E_\odot$): -7.575250836120401}
# Executing for Target Energy: {Parameter($E_\odot$): -7.474916387959866}
# Executing for Target Energy: {Parameter($E_\odot$): -7.374581939799331}
# Executing for Target Energy: {Parameter($E_\odot$): -7.274247491638795}
# Executing for Target Energy: {Parameter($E_\odot$): -7.173913043478261}
# Executing for Target Energy: {Parameter($E_\odot$): -7.073578595317725}
# Executing for Target Energy: {Parameter($E_\odot$): -6.973244147157191}
# Executing for Target Energy: {Parameter($E_\odot$): -6.872909698996656}
# Executing for Target Energy: {Parameter($E_\odot$): -6.77257525083612}
# Executing for Target Energy: {Parameter($E_\odot$): -6.672240802675585}
# Executing for Target Energy: {Parameter($E_\odot$): -6.5719063545150505}
# Executing for Target Energy: {Parameter($E_\odot$): -6.471571906354514}
# Executing for Target Energy: {Parameter($E_\odot$): -6.3712374581939795}
# Executing for Target Energy: {Parameter($E_\odot$): -6.270903010033445}
# Executing for Target Energy: {Parameter($E_\odot$): -6.17056856187291}
# Executing for Target Energy: {Parameter($E_\odot$): -6.070234113712374}
# Executing for Target Energy: {Parameter($E_\odot$): -5.969899665551839}
# Executing for Target Energy: {Parameter($E_\odot$): -5.869565217391305}
# Executing for Target Energy: {Parameter($E_\odot$): -5.769230769230768}
# Executing for Target Energy: {Parameter($E_\odot$): -5.668896321070234}
# Executing for Target Energy: {Parameter($E_\odot$): -5.568561872909699}
# Executing for Target Energy: {Parameter($E_\odot$): -5.4682274247491645}
# Executing for Target Energy: {Parameter($E_\odot$): -5.367892976588628}
# Executing for Target Energy: {Parameter($E_\odot$): -5.2675585284280935}
# Executing for Target Energy: {Parameter($E_\odot$): -5.167224080267559}
# Executing for Target Energy: {Parameter($E_\odot$): -5.0668896321070225}
# Executing for Target Energy: {Parameter($E_\odot$): -4.966555183946488}
# Executing for Target Energy: {Parameter($E_\odot$): -4.866220735785953}
# Executing for Target Energy: {Parameter($E_\odot$): -4.765886287625419}
# Executing for Target Energy: {Parameter($E_\odot$): -4.665551839464882}
# Executing for Target Energy: {Parameter($E_\odot$): -4.565217391304348}
# Executing for Target Energy: {Parameter($E_\odot$): -4.464882943143813}
# Executing for Target Energy: {Parameter($E_\odot$): -4.364548494983277}
# Executing for Target Energy: {Parameter($E_\odot$): -4.264214046822742}
# Executing for Target Energy: {Parameter($E_\odot$): -4.1638795986622075}
# Executing for Target Energy: {Parameter($E_\odot$): -4.063545150501671}
# Executing for Target Energy: {Parameter($E_\odot$): -3.9632107023411365}
# Executing for Target Energy: {Parameter($E_\odot$): -3.862876254180602}
# Executing for Target Energy: {Parameter($E_\odot$): -3.7625418060200673}
# Executing for Target Energy: {Parameter($E_\odot$): -3.662207357859531}
# Executing for Target Energy: {Parameter($E_\odot$): -3.5618729096989963}
# Executing for Target Energy: {Parameter($E_\odot$): -3.4615384615384617}
# Executing for Target Energy: {Parameter($E_\odot$): -3.3612040133779253}
# Executing for Target Energy: {Parameter($E_\odot$): -3.2608695652173907}
# Executing for Target Energy: {Parameter($E_\odot$): -3.160535117056856}
# Executing for Target Energy: {Parameter($E_\odot$): -3.0602006688963215}
# Executing for Target Energy: {Parameter($E_\odot$): -2.959866220735785}
# Executing for Target Energy: {Parameter($E_\odot$): -2.8595317725752505}
# Executing for Target Energy: {Parameter($E_\odot$): -2.759197324414716}
# Executing for Target Energy: {Parameter($E_\odot$): -2.6588628762541795}
# Executing for Target Energy: {Parameter($E_\odot$): -2.558528428093645}
# Executing for Target Energy: {Parameter($E_\odot$): -2.4581939799331103}
# Executing for Target Energy: {Parameter($E_\odot$): -2.3578595317725757}
# Executing for Target Energy: {Parameter($E_\odot$): -2.2575250836120393}
# Executing for Target Energy: {Parameter($E_\odot$): -2.1571906354515047}
# Executing for Target Energy: {Parameter($E_\odot$): -2.05685618729097}
# Executing for Target Energy: {Parameter($E_\odot$): -1.9565217391304337}
# Executing for Target Energy: {Parameter($E_\odot$): -1.856187290969899}
# Executing for Target Energy: {Parameter($E_\odot$): -1.7558528428093645}
# Executing for Target Energy: {Parameter($E_\odot$): -1.6555183946488299}
# Executing for Target Energy: {Parameter($E_\odot$): -1.5551839464882935}
# Executing for Target Energy: {Parameter($E_\odot$): -1.454849498327759}
# Executing for Target Energy: {Parameter($E_\odot$): -1.3545150501672243}
# Executing for Target Energy: {Parameter($E_\odot$): -1.254180602006688}
# Executing for Target Energy: {Parameter($E_\odot$): -1.1538461538461533}
# Executing for Target Energy: {Parameter($E_\odot$): -1.0535117056856187}
# Executing for Target Energy: {Parameter($E_\odot$): -0.9531772575250841}
# Executing for Target Energy: {Parameter($E_\odot$): -0.8528428093645477}
# Executing for Target Energy: {Parameter($E_\odot$): -0.7525083612040131}
# Executing for Target Energy: {Parameter($E_\odot$): -0.6521739130434785}
# Executing for Target Energy: {Parameter($E_\odot$): -0.5518394648829421}
# Executing for Target Energy: {Parameter($E_\odot$): -0.4515050167224075}
# Executing for Target Energy: {Parameter($E_\odot$): -0.3511705685618729}
# Executing for Target Energy: {Parameter($E_\odot$): -0.2508361204013383}
# Executing for Target Energy: {Parameter($E_\odot$): -0.1505016722408019}
# Executing for Target Energy: {Parameter($E_\odot$): -0.0501672240802673}
# Executing for Target Energy: {Parameter($E_\odot$): 0.0501672240802673}
# Executing for Target Energy: {Parameter($E_\odot$): 0.15050167224080369}
# Executing for Target Energy: {Parameter($E_\odot$): 0.2508361204013383}
# Executing for Target Energy: {Parameter($E_\odot$): 0.3511705685618729}
# Executing for Target Energy: {Parameter($E_\odot$): 0.4515050167224093}
# Executing for Target Energy: {Parameter($E_\odot$): 0.5518394648829439}
# Executing for Target Energy: {Parameter($E_\odot$): 0.6521739130434785}
# Executing for Target Energy: {Parameter($E_\odot$): 0.7525083612040131}
# Executing for Target Energy: {Parameter($E_\odot$): 0.8528428093645495}
# Executing for Target Energy: {Parameter($E_\odot$): 0.9531772575250841}
# Executing for Target Energy: {Parameter($E_\odot$): 1.0535117056856187}
# Executing for Target Energy: {Parameter($E_\odot$): 1.1538461538461533}
# Executing for Target Energy: {Parameter($E_\odot$): 1.254180602006688}
# Executing for Target Energy: {Parameter($E_\odot$): 1.354515050167226}
# Executing for Target Energy: {Parameter($E_\odot$): 1.4548494983277607}
# Executing for Target Energy: {Parameter($E_\odot$): 1.5551839464882953}
# Executing for Target Energy: {Parameter($E_\odot$): 1.6555183946488299}
# Executing for Target Energy: {Parameter($E_\odot$): 1.7558528428093645}
# Executing for Target Energy: {Parameter($E_\odot$): 1.856187290969899}
# Executing for Target Energy: {Parameter($E_\odot$): 1.9565217391304337}
# Executing for Target Energy: {Parameter($E_\odot$): 2.056856187290972}
# Executing for Target Energy: {Parameter($E_\odot$): 2.1571906354515065}
# Executing for Target Energy: {Parameter($E_\odot$): 2.257525083612041}
# Executing for Target Energy: {Parameter($E_\odot$): 2.3578595317725757}
# Executing for Target Energy: {Parameter($E_\odot$): 2.4581939799331103}
# Executing for Target Energy: {Parameter($E_\odot$): 2.558528428093645}
# Executing for Target Energy: {Parameter($E_\odot$): 2.6588628762541795}
# Executing for Target Energy: {Parameter($E_\odot$): 2.7591973244147177}
# Executing for Target Energy: {Parameter($E_\odot$): 2.8595317725752523}
# Executing for Target Energy: {Parameter($E_\odot$): 2.959866220735787}
# Executing for Target Energy: {Parameter($E_\odot$): 3.0602006688963215}
# Executing for Target Energy: {Parameter($E_\odot$): 3.160535117056856}
# Executing for Target Energy: {Parameter($E_\odot$): 3.2608695652173907}
# Executing for Target Energy: {Parameter($E_\odot$): 3.3612040133779253}
# Executing for Target Energy: {Parameter($E_\odot$): 3.4615384615384635}
# Executing for Target Energy: {Parameter($E_\odot$): 3.561872909698998}
# Executing for Target Energy: {Parameter($E_\odot$): 3.6622073578595327}
# Executing for Target Energy: {Parameter($E_\odot$): 3.7625418060200673}
# Executing for Target Energy: {Parameter($E_\odot$): 3.862876254180602}
# Executing for Target Energy: {Parameter($E_\odot$): 3.9632107023411365}
# Executing for Target Energy: {Parameter($E_\odot$): 4.063545150501671}
# Executing for Target Energy: {Parameter($E_\odot$): 4.163879598662209}
# Executing for Target Energy: {Parameter($E_\odot$): 4.264214046822744}
# Executing for Target Energy: {Parameter($E_\odot$): 4.3645484949832785}
# Executing for Target Energy: {Parameter($E_\odot$): 4.464882943143813}
# Executing for Target Energy: {Parameter($E_\odot$): 4.565217391304348}
# Executing for Target Energy: {Parameter($E_\odot$): 4.665551839464882}
# Executing for Target Energy: {Parameter($E_\odot$): 4.765886287625417}
# Executing for Target Energy: {Parameter($E_\odot$): 4.866220735785955}
# Executing for Target Energy: {Parameter($E_\odot$): 4.96655518394649}
# Executing for Target Energy: {Parameter($E_\odot$): 5.066889632107024}
# Executing for Target Energy: {Parameter($E_\odot$): 5.167224080267559}
# Executing for Target Energy: {Parameter($E_\odot$): 5.2675585284280935}
# Executing for Target Energy: {Parameter($E_\odot$): 5.367892976588628}
# Executing for Target Energy: {Parameter($E_\odot$): 5.468227424749163}
# Executing for Target Energy: {Parameter($E_\odot$): 5.568561872909701}
# Executing for Target Energy: {Parameter($E_\odot$): 5.6688963210702354}
# Executing for Target Energy: {Parameter($E_\odot$): 5.76923076923077}
# Executing for Target Energy: {Parameter($E_\odot$): 5.869565217391305}
# Executing for Target Energy: {Parameter($E_\odot$): 5.969899665551839}
# Executing for Target Energy: {Parameter($E_\odot$): 6.070234113712374}
# Executing for Target Energy: {Parameter($E_\odot$): 6.1705685618729085}
# Executing for Target Energy: {Parameter($E_\odot$): 6.270903010033447}
# Executing for Target Energy: {Parameter($E_\odot$): 6.371237458193981}
# Executing for Target Energy: {Parameter($E_\odot$): 6.471571906354516}
# Executing for Target Energy: {Parameter($E_\odot$): 6.5719063545150505}
# Executing for Target Energy: {Parameter($E_\odot$): 6.672240802675585}
# Executing for Target Energy: {Parameter($E_\odot$): 6.77257525083612}
# Executing for Target Energy: {Parameter($E_\odot$): 6.872909698996658}
# Executing for Target Energy: {Parameter($E_\odot$): 6.973244147157192}
# Executing for Target Energy: {Parameter($E_\odot$): 7.073578595317727}
# Executing for Target Energy: {Parameter($E_\odot$): 7.173913043478262}
# Executing for Target Energy: {Parameter($E_\odot$): 7.274247491638796}
# Executing for Target Energy: {Parameter($E_\odot$): 7.374581939799331}
# Executing for Target Energy: {Parameter($E_\odot$): 7.4749163879598655}
# Executing for Target Energy: {Parameter($E_\odot$): 7.575250836120404}
# Executing for Target Energy: {Parameter($E_\odot$): 7.675585284280938}
# Executing for Target Energy: {Parameter($E_\odot$): 7.775919732441473}
# Executing for Target Energy: {Parameter($E_\odot$): 7.876254180602007}
# Executing for Target Energy: {Parameter($E_\odot$): 7.976588628762542}
# Executing for Target Energy: {Parameter($E_\odot$): 8.076923076923077}
# Executing for Target Energy: {Parameter($E_\odot$): 8.177257525083611}
# Executing for Target Energy: {Parameter($E_\odot$): 8.27759197324415}
# Executing for Target Energy: {Parameter($E_\odot$): 8.377926421404684}
# Executing for Target Energy: {Parameter($E_\odot$): 8.478260869565219}
# Executing for Target Energy: {Parameter($E_\odot$): 8.578595317725753}
# Executing for Target Energy: {Parameter($E_\odot$): 8.678929765886288}
# Executing for Target Energy: {Parameter($E_\odot$): 8.779264214046822}
# Executing for Target Energy: {Parameter($E_\odot$): 8.879598662207357}
# Executing for Target Energy: {Parameter($E_\odot$): 8.979933110367895}
# Executing for Target Energy: {Parameter($E_\odot$): 9.08026755852843}
# Executing for Target Energy: {Parameter($E_\odot$): 9.180602006688964}
# Executing for Target Energy: {Parameter($E_\odot$): 9.280936454849499}
# Executing for Target Energy: {Parameter($E_\odot$): 9.381270903010034}
# Executing for Target Energy: {Parameter($E_\odot$): 9.481605351170568}
# Executing for Target Energy: {Parameter($E_\odot$): 9.581939799331103}
# Executing for Target Energy: {Parameter($E_\odot$): 9.682274247491641}
# Executing for Target Energy: {Parameter($E_\odot$): 9.782608695652176}
# Executing for Target Energy: {Parameter($E_\odot$): 9.88294314381271}
# Executing for Target Energy: {Parameter($E_\odot$): 9.983277591973245}
# Executing for Target Energy: {Parameter($E_\odot$): 10.08361204013378}
# Executing for Target Energy: {Parameter($E_\odot$): 10.183946488294314}
# Executing for Target Energy: {Parameter($E_\odot$): 10.284280936454849}
# Executing for Target Energy: {Parameter($E_\odot$): 10.384615384615387}
# Executing for Target Energy: {Parameter($E_\odot$): 10.484949832775921}
# Executing for Target Energy: {Parameter($E_\odot$): 10.585284280936456}
# Executing for Target Energy: {Parameter($E_\odot$): 10.68561872909699}
# Executing for Target Energy: {Parameter($E_\odot$): 10.785953177257525}
# Executing for Target Energy: {Parameter($E_\odot$): 10.88628762541806}
# Executing for Target Energy: {Parameter($E_\odot$): 10.986622073578594}
# Executing for Target Energy: {Parameter($E_\odot$): 11.086956521739133}
# Executing for Target Energy: {Parameter($E_\odot$): 11.187290969899667}
# Executing for Target Energy: {Parameter($E_\odot$): 11.287625418060202}
# Executing for Target Energy: {Parameter($E_\odot$): 11.387959866220736}
# Executing for Target Energy: {Parameter($E_\odot$): 11.488294314381271}
# Executing for Target Energy: {Parameter($E_\odot$): 11.588628762541806}
# Executing for Target Energy: {Parameter($E_\odot$): 11.68896321070234}
# Executing for Target Energy: {Parameter($E_\odot$): 11.789297658862878}
# Executing for Target Energy: {Parameter($E_\odot$): 11.889632107023413}
# Executing for Target Energy: {Parameter($E_\odot$): 11.989966555183948}
# Executing for Target Energy: {Parameter($E_\odot$): 12.090301003344482}
# Executing for Target Energy: {Parameter($E_\odot$): 12.190635451505017}
# Executing for Target Energy: {Parameter($E_\odot$): 12.290969899665551}
# Executing for Target Energy: {Parameter($E_\odot$): 12.391304347826086}
# Executing for Target Energy: {Parameter($E_\odot$): 12.491638795986624}
# Executing for Target Energy: {Parameter($E_\odot$): 12.591973244147159}
# Executing for Target Energy: {Parameter($E_\odot$): 12.692307692307693}
# Executing for Target Energy: {Parameter($E_\odot$): 12.792642140468228}
# Executing for Target Energy: {Parameter($E_\odot$): 12.892976588628763}
# Executing for Target Energy: {Parameter($E_\odot$): 12.993311036789297}
# Executing for Target Energy: {Parameter($E_\odot$): 13.093645484949832}
# Executing for Target Energy: {Parameter($E_\odot$): 13.19397993311037}
# Executing for Target Energy: {Parameter($E_\odot$): 13.294314381270905}
# Executing for Target Energy: {Parameter($E_\odot$): 13.39464882943144}
# Executing for Target Energy: {Parameter($E_\odot$): 13.494983277591974}
# Executing for Target Energy: {Parameter($E_\odot$): 13.595317725752508}
# Executing for Target Energy: {Parameter($E_\odot$): 13.695652173913043}
# Executing for Target Energy: {Parameter($E_\odot$): 13.795986622073578}
# Executing for Target Energy: {Parameter($E_\odot$): 13.896321070234116}
# Executing for Target Energy: {Parameter($E_\odot$): 13.99665551839465}
# Executing for Target Energy: {Parameter($E_\odot$): 14.096989966555185}
# Executing for Target Energy: {Parameter($E_\odot$): 14.19732441471572}
# Executing for Target Energy: {Parameter($E_\odot$): 14.297658862876254}
# Executing for Target Energy: {Parameter($E_\odot$): 14.397993311036789}
# Executing for Target Energy: {Parameter($E_\odot$): 14.498327759197323}
# Executing for Target Energy: {Parameter($E_\odot$): 14.598662207357862}
# Executing for Target Energy: {Parameter($E_\odot$): 14.698996655518396}
# Executing for Target Energy: {Parameter($E_\odot$): 14.79933110367893}
# Executing for Target Energy: {Parameter($E_\odot$): 14.899665551839465}
# Executing for Target Energy: {Parameter($E_\odot$): 15.0}

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# This extracts the probabilities for the 0 bitcounts from our obtained data
values_list = []
for d in data:
    if 0 in d:
        values_list.append(d[0])
    else:
        values_list.append(0.0)
print(len(values_list))
print(len(targetenergies))

# Define a Gaussian function
def gaussian(x, amp, cen, wid):
    return amp * np.exp(-(x-cen)**2 / (2*wid**2))

# Define a sum of multiple Gaussians
def sum_of_gaussians(x, *params):
    n_gaussians = len(params) // 3
    result = np.zeros_like(x)
    for i in range(n_gaussians):
        amp = params[i*3]
        cen = params[i*3 + 1]
        wid = params[i*3 + 2]
        result += gaussian(x, amp, cen, wid)
    return result

# Initial guess for the parameters: amplitudes, centers, and widths of the Gaussians
initial_guess = [
    1, -13, 1
]

# Fit the sum of Gaussians to the data
popt, pcov = curve_fit(sum_of_gaussians, targetenergies, values_list, p0=initial_guess)

# Extract the fitted parameters
fitted_params = popt

# Generate x values for plotting the fit
x_fit = np.linspace(min(targetenergies), max(targetenergies), 1000)
y_fit = sum_of_gaussians(x_fit, *fitted_params)

# Plot the data and the fit
plt.scatter(targetenergies, values_list, label='Data')
plt.plot(x_fit, y_fit, color='red', label='Sum of Gaussians fit')
plt.grid()
plt.xlabel('Target Energy')
plt.ylabel('Average Probability')
plt.axvline(x = -12.53, color = 'green', label = 'Ground State Energy')
plt.legend()
plt.show()

# Print the peaks (centers) of the Gaussians
n_gaussians = len(fitted_params) // 3
peaks = [fitted_params[i*3 + 1] for i in range(n_gaussians)]
print(f'The peaks (centers) of the Gaussians are at: {peaks}')
# Out:
# 300
# 300
# The peaks (centers) of the Gaussians are at: [-12.568051638782915]
